# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .xlsx sin indice
data = pd.read_excel('inmuebles2.xlsx')

# %%
#Convertir DataFrame a CSV
data.to_csv("inmuebles2.csv")

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_csv('inmuebles2.csv') 
data
# Out:
#       Unnamed: 0  \
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 3333        3333
# 3334        3334
# 3335        3335
# 3336        3336
# 3337        3337
#
#      Esta es una base de datos que describe las operaciones inmobiliarias de una empresa  \
# 0                                            Referencia
# 1                                                     1
# 2                                                     2
# 3                                                     3
# 4                                                     4
# ...                                                 ...
# 3333                                               3333
# 3334                                               3334
# 3335                                               3335
# 3336                                               3336
# 3337                                               3337
#
#                Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0              Fecha Alta        Tipo  Operación  Provincia  Superficie
# 1     2004-01-01 00:00:00     Parking   Alquiler     Lleida         291
# 2     2004-01-01 00:00:00       Local      Venta     Girona         185
# 3     2004-01-01 00:00:00     Oficina   Alquiler     Girona          82
# 4     2004-01-02 00:00:00     Parking   Alquiler     Girona         285
# ...                   ...         ...        ...        ...         ...
# 3333  2007-04-29 00:00:00  Industrial   Alquiler     Lleida         221
# 3334  2007-04-29 00:00:00        Piso   Alquiler     Girona          55
# 3335  2007-04-30 00:00:00       Suelo      Venta  Tarragona          78
# 3336  2007-04-30 00:00:00        Piso   Alquiler  Barcelona          88
# 3337  2007-04-30 00:00:00     Parking      Venta     Lleida         NaN
#
#         Unnamed: 6           Unnamed: 7 Unnamed: 8
# 0     Precio Venta          Fecha Venta   Vendedor
# 1          2133903  2004-06-19 00:00:00     Carmen
# 2          1945424  2004-04-19 00:00:00      Pedro
# 3              NaN  2004-11-08 00:00:00    Joaquín
# 4              NaN  2004-04-27 00:00:00      Jesús
# ...            ...                  ...        ...
# 3333       1450644                  NaN        NaN
# 3334        454080                  NaN        NaN
# 3335        740688                  NaN        NaN
# 3336        397408                  NaN        NaN
# 3337       2140712                  NaN        NaN
#
# [3338 rows x 10 columns]

# %%
#Eliminar primera fila o filas innecesarias
data1= pd.read_csv('inmuebles2.csv', skiprows=1, low_memory=False)
data1
# Out:
#          0  Referencia           Fecha Alta        Tipo Operación  Provincia  \
# 0        1           1  2004-01-01 00:00:00     Parking  Alquiler     Lleida
# 1        2           2  2004-01-01 00:00:00       Local     Venta     Girona
# 2        3           3  2004-01-01 00:00:00     Oficina  Alquiler     Girona
# 3        4           4  2004-01-02 00:00:00     Parking  Alquiler     Girona
# 4        5           5  2004-01-02 00:00:00       Suelo     Venta  Tarragona
# ...    ...         ...                  ...         ...       ...        ...
# 3332  3333        3333  2007-04-29 00:00:00  Industrial  Alquiler     Lleida
# 3333  3334        3334  2007-04-29 00:00:00        Piso  Alquiler     Girona
# 3334  3335        3335  2007-04-30 00:00:00       Suelo     Venta  Tarragona
# 3335  3336        3336  2007-04-30 00:00:00        Piso  Alquiler  Barcelona
# 3336  3337        3337  2007-04-30 00:00:00     Parking     Venta     Lleida
#
#       Superficie  Precio Venta          Fecha Venta Vendedor
# 0          291.0     2133903.0  2004-06-19 00:00:00   Carmen
# 1          185.0     1945424.0  2004-04-19 00:00:00    Pedro
# 2           82.0           NaN  2004-11-08 00:00:00  Joaquín
# 3          285.0           NaN  2004-04-27 00:00:00    Jesús
# 4          152.0      185000.0  2004-07-10 00:00:00    María
# ...          ...           ...                  ...      ...
# 3332       221.0     1450644.0                  NaN      NaN
# 3333        55.0      454080.0                  NaN      NaN
# 3334        78.0      740688.0                  NaN      NaN
# 3335        88.0      397408.0                  NaN      NaN
# 3336         NaN     2140712.0                  NaN      NaN
#
# [3337 rows x 10 columns]

# %%
#Eliminar columnas innecesarias
data2= data1.drop(['0','Referencia'], axis=1)
data2
# Out:
#                Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0     2004-01-01 00:00:00     Parking  Alquiler     Lleida       291.0
# 1     2004-01-01 00:00:00       Local     Venta     Girona       185.0
# 2     2004-01-01 00:00:00     Oficina  Alquiler     Girona        82.0
# 3     2004-01-02 00:00:00     Parking  Alquiler     Girona       285.0
# 4     2004-01-02 00:00:00       Suelo     Venta  Tarragona       152.0
# ...                   ...         ...       ...        ...         ...
# 3332  2007-04-29 00:00:00  Industrial  Alquiler     Lleida       221.0
# 3333  2007-04-29 00:00:00        Piso  Alquiler     Girona        55.0
# 3334  2007-04-30 00:00:00       Suelo     Venta  Tarragona        78.0
# 3335  2007-04-30 00:00:00        Piso  Alquiler  Barcelona        88.0
# 3336  2007-04-30 00:00:00     Parking     Venta     Lleida         NaN
#
#       Precio Venta          Fecha Venta Vendedor
# 0        2133903.0  2004-06-19 00:00:00   Carmen
# 1        1945424.0  2004-04-19 00:00:00    Pedro
# 2              NaN  2004-11-08 00:00:00  Joaquín
# 3              NaN  2004-04-27 00:00:00    Jesús
# 4         185000.0  2004-07-10 00:00:00    María
# ...            ...                  ...      ...
# 3332     1450644.0                  NaN      NaN
# 3333      454080.0                  NaN      NaN
# 3334      740688.0                  NaN      NaN
# 3335      397408.0                  NaN      NaN
# 3336     2140712.0                  NaN      NaN
#
# [3337 rows x 8 columns]

# %%
#Identificar valores nulos
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# Fecha Alta        2
# Tipo              2
# Operación         1
# Provincia         4
# Superficie        4
# Precio Venta      6
# Fecha Venta     578
# Vendedor        578
# dtype: int64

# %%
#Realizamos una copia del dataframe
data3=data2.copy()

# %%
#Sustituir valores nulos con promedio o media
data3["Superficie"]=data3["Superficie"].fillna(round(data2["Superficie"].mean(),1))
data3
# Out:
#                Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0     2004-01-01 00:00:00     Parking  Alquiler     Lleida       291.0
# 1     2004-01-01 00:00:00       Local     Venta     Girona       185.0
# 2     2004-01-01 00:00:00     Oficina  Alquiler     Girona        82.0
# 3     2004-01-02 00:00:00     Parking  Alquiler     Girona       285.0
# 4     2004-01-02 00:00:00       Suelo     Venta  Tarragona       152.0
# ...                   ...         ...       ...        ...         ...
# 3332  2007-04-29 00:00:00  Industrial  Alquiler     Lleida       221.0
# 3333  2007-04-29 00:00:00        Piso  Alquiler     Girona        55.0
# 3334  2007-04-30 00:00:00       Suelo     Venta  Tarragona        78.0
# 3335  2007-04-30 00:00:00        Piso  Alquiler  Barcelona        88.0
# 3336  2007-04-30 00:00:00     Parking     Venta     Lleida       170.2
#
#       Precio Venta          Fecha Venta Vendedor
# 0        2133903.0  2004-06-19 00:00:00   Carmen
# 1        1945424.0  2004-04-19 00:00:00    Pedro
# 2              NaN  2004-11-08 00:00:00  Joaquín
# 3              NaN  2004-04-27 00:00:00    Jesús
# 4         185000.0  2004-07-10 00:00:00    María
# ...            ...                  ...      ...
# 3332     1450644.0                  NaN      NaN
# 3333      454080.0                  NaN      NaN
# 3334      740688.0                  NaN      NaN
# 3335      397408.0                  NaN      NaN
# 3336     2140712.0                  NaN      NaN
#
# [3337 rows x 8 columns]

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# Fecha Alta        2
# Tipo              2
# Operación         1
# Provincia         4
# Superficie        0
# Precio Venta      6
# Fecha Venta     578
# Vendedor        578
# dtype: int64

# %%
#Sustituir valores nulos con mediana
data3["Precio Venta"]=data3["Precio Venta"].fillna(round(data2["Precio Venta"].median(),1))
data3
# Out:
#                Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0     2004-01-01 00:00:00     Parking  Alquiler     Lleida       291.0
# 1     2004-01-01 00:00:00       Local     Venta     Girona       185.0
# 2     2004-01-01 00:00:00     Oficina  Alquiler     Girona        82.0
# 3     2004-01-02 00:00:00     Parking  Alquiler     Girona       285.0
# 4     2004-01-02 00:00:00       Suelo     Venta  Tarragona       152.0
# ...                   ...         ...       ...        ...         ...
# 3332  2007-04-29 00:00:00  Industrial  Alquiler     Lleida       221.0
# 3333  2007-04-29 00:00:00        Piso  Alquiler     Girona        55.0
# 3334  2007-04-30 00:00:00       Suelo     Venta  Tarragona        78.0
# 3335  2007-04-30 00:00:00        Piso  Alquiler  Barcelona        88.0
# 3336  2007-04-30 00:00:00     Parking     Venta     Lleida       170.2
#
#       Precio Venta          Fecha Venta Vendedor
# 0        2133903.0  2004-06-19 00:00:00   Carmen
# 1        1945424.0  2004-04-19 00:00:00    Pedro
# 2        1121906.0  2004-11-08 00:00:00  Joaquín
# 3        1121906.0  2004-04-27 00:00:00    Jesús
# 4         185000.0  2004-07-10 00:00:00    María
# ...            ...                  ...      ...
# 3332     1450644.0                  NaN      NaN
# 3333      454080.0                  NaN      NaN
# 3334      740688.0                  NaN      NaN
# 3335      397408.0                  NaN      NaN
# 3336     2140712.0                  NaN      NaN
#
# [3337 rows x 8 columns]

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# Fecha Alta        2
# Tipo              2
# Operación         1
# Provincia         4
# Superficie        0
# Precio Venta      0
# Fecha Venta     578
# Vendedor        578
# dtype: int64

# %%
#Eliminamos filas con nulos
data4= data3.dropna(0)
data4
# Out:
# /var/folders/zv/01rx8f0176x702fr56drfp1m0000gn/T/ipykernel_2007/3461269117.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   data4= data3.dropna(0)
#                Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0     2004-01-01 00:00:00     Parking  Alquiler     Lleida       291.0
# 1     2004-01-01 00:00:00       Local     Venta     Girona       185.0
# 2     2004-01-01 00:00:00     Oficina  Alquiler     Girona        82.0
# 3     2004-01-02 00:00:00     Parking  Alquiler     Girona       285.0
# 4     2004-01-02 00:00:00       Suelo     Venta  Tarragona       152.0
# ...                   ...         ...       ...        ...         ...
# 3016  2006-12-30 00:00:00        Casa  Alquiler  Barcelona       264.0
# 3017  2006-12-31 00:00:00     Oficina     Venta     Lleida        69.0
# 3030  2007-01-07 00:00:00  Industrial  Alquiler     Lleida       196.0
# 3042  2007-01-09 00:00:00       Local     Venta     Lleida        92.0
# 3045  2007-01-10 00:00:00     Parking     Venta  Barcelona       233.0
#
#       Precio Venta          Fecha Venta Vendedor
# 0        2133903.0  2004-06-19 00:00:00   Carmen
# 1        1945424.0  2004-04-19 00:00:00    Pedro
# 2        1121906.0  2004-11-08 00:00:00  Joaquín
# 3        1121906.0  2004-04-27 00:00:00    Jesús
# 4         185000.0  2004-07-10 00:00:00    María
# ...            ...                  ...      ...
# 3016     1060488.0  2007-04-28 00:00:00  Joaquín
# 3017      483828.0  2007-05-05 00:00:00    Pedro
# 3030      904344.0  2007-04-20 00:00:00    Pedro
# 3042      709596.0  2007-04-17 00:00:00   Carmen
# 3045     1077858.0  2007-04-30 00:00:00    María
#
# [2755 rows x 8 columns]

# %%
#Corroboramos valores nulos
valores_nulos=data4.isnull().sum()
valores_nulos
# Out:
# Fecha Alta      0
# Tipo            0
# Operación       0
# Provincia       0
# Superficie      0
# Precio Venta    0
# Fecha Venta     0
# Vendedor        0
# dtype: int64

# %%
#Sustituir valores nulos por un valor numérico en  concreto 
#Filtro por columnas
#Actividad_total=data4.iloc[ : , [6]]
data3["Fecha Alta"]= data3["Fecha Alta"].fillna(10) 
data3
# Out:
#                Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0     2004-01-01 00:00:00     Parking  Alquiler     Lleida       291.0
# 1     2004-01-01 00:00:00       Local     Venta     Girona       185.0
# 2     2004-01-01 00:00:00     Oficina  Alquiler     Girona        82.0
# 3     2004-01-02 00:00:00     Parking  Alquiler     Girona       285.0
# 4     2004-01-02 00:00:00       Suelo     Venta  Tarragona       152.0
# ...                   ...         ...       ...        ...         ...
# 3332  2007-04-29 00:00:00  Industrial  Alquiler     Lleida       221.0
# 3333  2007-04-29 00:00:00        Piso  Alquiler     Girona        55.0
# 3334  2007-04-30 00:00:00       Suelo     Venta  Tarragona        78.0
# 3335  2007-04-30 00:00:00        Piso  Alquiler  Barcelona        88.0
# 3336  2007-04-30 00:00:00     Parking     Venta     Lleida       170.2
#
#       Precio Venta          Fecha Venta Vendedor
# 0        2133903.0  2004-06-19 00:00:00   Carmen
# 1        1945424.0  2004-04-19 00:00:00    Pedro
# 2        1121906.0  2004-11-08 00:00:00  Joaquín
# 3        1121906.0  2004-04-27 00:00:00    Jesús
# 4         185000.0  2004-07-10 00:00:00    María
# ...            ...                  ...      ...
# 3332     1450644.0                  NaN      NaN
# 3333      454080.0                  NaN      NaN
# 3334      740688.0                  NaN      NaN
# 3335      397408.0                  NaN      NaN
# 3336     2140712.0                  NaN      NaN
#
# [3337 rows x 8 columns]

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# Fecha Alta        0
# Tipo              2
# Operación         1
# Provincia         4
# Superficie        0
# Precio Venta      0
# Fecha Venta     578
# Vendedor        578
# dtype: int64

# %%
#Sustituir valores nulos por un string en  concreto 
#Filtro por columnas
data3["Fecha Venta"] =data3["Fecha Venta"].fillna("2030-06-19 00:00:00") 
data3
# Out:
#                Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0     2004-01-01 00:00:00     Parking  Alquiler     Lleida       291.0
# 1     2004-01-01 00:00:00       Local     Venta     Girona       185.0
# 2     2004-01-01 00:00:00     Oficina  Alquiler     Girona        82.0
# 3     2004-01-02 00:00:00     Parking  Alquiler     Girona       285.0
# 4     2004-01-02 00:00:00       Suelo     Venta  Tarragona       152.0
# ...                   ...         ...       ...        ...         ...
# 3332  2007-04-29 00:00:00  Industrial  Alquiler     Lleida       221.0
# 3333  2007-04-29 00:00:00        Piso  Alquiler     Girona        55.0
# 3334  2007-04-30 00:00:00       Suelo     Venta  Tarragona        78.0
# 3335  2007-04-30 00:00:00        Piso  Alquiler  Barcelona        88.0
# 3336  2007-04-30 00:00:00     Parking     Venta     Lleida       170.2
#
#       Precio Venta          Fecha Venta Vendedor
# 0        2133903.0  2004-06-19 00:00:00   Carmen
# 1        1945424.0  2004-04-19 00:00:00    Pedro
# 2        1121906.0  2004-11-08 00:00:00  Joaquín
# 3        1121906.0  2004-04-27 00:00:00    Jesús
# 4         185000.0  2004-07-10 00:00:00    María
# ...            ...                  ...      ...
# 3332     1450644.0  2030-06-19 00:00:00      NaN
# 3333      454080.0  2030-06-19 00:00:00      NaN
# 3334      740688.0  2030-06-19 00:00:00      NaN
# 3335      397408.0  2030-06-19 00:00:00      NaN
# 3336     2140712.0  2030-06-19 00:00:00      NaN
#
# [3337 rows x 8 columns]

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# Fecha Alta        0
# Tipo              2
# Operación         1
# Provincia         4
# Superficie        0
# Precio Venta      0
# Fecha Venta       0
# Vendedor        578
# dtype: int64

# %%
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
data3["Tipo"] =data3["Tipo"].fillna(method="ffill") 
data3
# Out:
#                Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0     2004-01-01 00:00:00     Parking  Alquiler     Lleida       291.0
# 1     2004-01-01 00:00:00       Local     Venta     Girona       185.0
# 2     2004-01-01 00:00:00     Oficina  Alquiler     Girona        82.0
# 3     2004-01-02 00:00:00     Parking  Alquiler     Girona       285.0
# 4     2004-01-02 00:00:00       Suelo     Venta  Tarragona       152.0
# ...                   ...         ...       ...        ...         ...
# 3332  2007-04-29 00:00:00  Industrial  Alquiler     Lleida       221.0
# 3333  2007-04-29 00:00:00        Piso  Alquiler     Girona        55.0
# 3334  2007-04-30 00:00:00       Suelo     Venta  Tarragona        78.0
# 3335  2007-04-30 00:00:00        Piso  Alquiler  Barcelona        88.0
# 3336  2007-04-30 00:00:00     Parking     Venta     Lleida       170.2
#
#       Precio Venta          Fecha Venta Vendedor
# 0        2133903.0  2004-06-19 00:00:00   Carmen
# 1        1945424.0  2004-04-19 00:00:00    Pedro
# 2        1121906.0  2004-11-08 00:00:00  Joaquín
# 3        1121906.0  2004-04-27 00:00:00    Jesús
# 4         185000.0  2004-07-10 00:00:00    María
# ...            ...                  ...      ...
# 3332     1450644.0  2030-06-19 00:00:00      NaN
# 3333      454080.0  2030-06-19 00:00:00      NaN
# 3334      740688.0  2030-06-19 00:00:00      NaN
# 3335      397408.0  2030-06-19 00:00:00      NaN
# 3336     2140712.0  2030-06-19 00:00:00      NaN
#
# [3337 rows x 8 columns]

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# Fecha Alta        0
# Tipo              0
# Operación         1
# Provincia         4
# Superficie        0
# Precio Venta      0
# Fecha Venta       0
# Vendedor        578
# dtype: int64

# %%
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
data3["Operación"] =data3["Operación"].fillna(method="bfill") 
data2
# Out:
#                Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0     2004-01-01 00:00:00     Parking  Alquiler     Lleida       291.0
# 1     2004-01-01 00:00:00       Local     Venta     Girona       185.0
# 2     2004-01-01 00:00:00     Oficina  Alquiler     Girona        82.0
# 3     2004-01-02 00:00:00     Parking  Alquiler     Girona       285.0
# 4     2004-01-02 00:00:00       Suelo     Venta  Tarragona       152.0
# ...                   ...         ...       ...        ...         ...
# 3332  2007-04-29 00:00:00  Industrial  Alquiler     Lleida       221.0
# 3333  2007-04-29 00:00:00        Piso  Alquiler     Girona        55.0
# 3334  2007-04-30 00:00:00       Suelo     Venta  Tarragona        78.0
# 3335  2007-04-30 00:00:00        Piso  Alquiler  Barcelona        88.0
# 3336  2007-04-30 00:00:00     Parking     Venta     Lleida         NaN
#
#       Precio Venta          Fecha Venta Vendedor
# 0        2133903.0  2004-06-19 00:00:00   Carmen
# 1        1945424.0  2004-04-19 00:00:00    Pedro
# 2              NaN  2004-11-08 00:00:00  Joaquín
# 3              NaN  2004-04-27 00:00:00    Jesús
# 4         185000.0  2004-07-10 00:00:00    María
# ...            ...                  ...      ...
# 3332     1450644.0                  NaN      NaN
# 3333      454080.0                  NaN      NaN
# 3334      740688.0                  NaN      NaN
# 3335      397408.0                  NaN      NaN
# 3336     2140712.0                  NaN      NaN
#
# [3337 rows x 8 columns]

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# Fecha Alta        0
# Tipo              0
# Operación         0
# Provincia         4
# Superficie        0
# Precio Venta      0
# Fecha Venta       0
# Vendedor        578
# dtype: int64

# %%
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
data3["Provincia"] =data3["Provincia"].fillna(method="bfill") 
data2
# Out:
#                Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0     2004-01-01 00:00:00     Parking  Alquiler     Lleida       291.0
# 1     2004-01-01 00:00:00       Local     Venta     Girona       185.0
# 2     2004-01-01 00:00:00     Oficina  Alquiler     Girona        82.0
# 3     2004-01-02 00:00:00     Parking  Alquiler     Girona       285.0
# 4     2004-01-02 00:00:00       Suelo     Venta  Tarragona       152.0
# ...                   ...         ...       ...        ...         ...
# 3332  2007-04-29 00:00:00  Industrial  Alquiler     Lleida       221.0
# 3333  2007-04-29 00:00:00        Piso  Alquiler     Girona        55.0
# 3334  2007-04-30 00:00:00       Suelo     Venta  Tarragona        78.0
# 3335  2007-04-30 00:00:00        Piso  Alquiler  Barcelona        88.0
# 3336  2007-04-30 00:00:00     Parking     Venta     Lleida         NaN
#
#       Precio Venta          Fecha Venta Vendedor
# 0        2133903.0  2004-06-19 00:00:00   Carmen
# 1        1945424.0  2004-04-19 00:00:00    Pedro
# 2              NaN  2004-11-08 00:00:00  Joaquín
# 3              NaN  2004-04-27 00:00:00    Jesús
# 4         185000.0  2004-07-10 00:00:00    María
# ...            ...                  ...      ...
# 3332     1450644.0                  NaN      NaN
# 3333      454080.0                  NaN      NaN
# 3334      740688.0                  NaN      NaN
# 3335      397408.0                  NaN      NaN
# 3336     2140712.0                  NaN      NaN
#
# [3337 rows x 8 columns]

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# Fecha Alta        0
# Tipo              0
# Operación         0
# Provincia         0
# Superficie        0
# Precio Venta      0
# Fecha Venta       0
# Vendedor        578
# dtype: int64

# %%
#Sustituir valores nulos por valores no nulos hacia adelante forward fill" ("ffill")
#Filtro por columnas
data3["Vendedor"] =data3["Vendedor"].fillna(method="ffill") 
data3
# Out:
#                Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0     2004-01-01 00:00:00     Parking  Alquiler     Lleida       291.0
# 1     2004-01-01 00:00:00       Local     Venta     Girona       185.0
# 2     2004-01-01 00:00:00     Oficina  Alquiler     Girona        82.0
# 3     2004-01-02 00:00:00     Parking  Alquiler     Girona       285.0
# 4     2004-01-02 00:00:00       Suelo     Venta  Tarragona       152.0
# ...                   ...         ...       ...        ...         ...
# 3332  2007-04-29 00:00:00  Industrial  Alquiler     Lleida       221.0
# 3333  2007-04-29 00:00:00        Piso  Alquiler     Girona        55.0
# 3334  2007-04-30 00:00:00       Suelo     Venta  Tarragona        78.0
# 3335  2007-04-30 00:00:00        Piso  Alquiler  Barcelona        88.0
# 3336  2007-04-30 00:00:00     Parking     Venta     Lleida       170.2
#
#       Precio Venta          Fecha Venta Vendedor
# 0        2133903.0  2004-06-19 00:00:00   Carmen
# 1        1945424.0  2004-04-19 00:00:00    Pedro
# 2        1121906.0  2004-11-08 00:00:00  Joaquín
# 3        1121906.0  2004-04-27 00:00:00    Jesús
# 4         185000.0  2004-07-10 00:00:00    María
# ...            ...                  ...      ...
# 3332     1450644.0  2030-06-19 00:00:00    María
# 3333      454080.0  2030-06-19 00:00:00    María
# 3334      740688.0  2030-06-19 00:00:00    María
# 3335      397408.0  2030-06-19 00:00:00    María
# 3336     2140712.0  2030-06-19 00:00:00    María
#
# [3337 rows x 8 columns]

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# Fecha Alta      0
# Tipo            0
# Operación       0
# Provincia       0
# Superficie      0
# Precio Venta    0
# Fecha Venta     0
# Vendedor        0
# dtype: int64

# %%
#Obtenemos la cuenta de los elementos nulos del dataframe completo
Cuenta_Total_Nulos= data4.isnull().sum().sum()
Cuenta_Total_Nulos
# Out:
# 0

# %%
#Convertir DataFrame a CSV
data3.to_csv("inmuebles_sin_nulos.csv")

# %%
#Realizamos histograma de variables cuantitativas
fig = plt.figure(figsize=(6,3))
plt.hist(x=data4["Superficie"], color='blue', rwidth=0.50)
plt.title('Histograma de Superficies')
plt.xlabel('Superficies')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
# Apilar los __DataFrames__ uno encima del otro
vertical_concat = pd.concat([data2, data], axis=0)


# Coloque los __DataFrames__ de lado a lado
horizontal_concat = pd.concat([data2, fecha], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/elicobos/Desktop/Plataformas/Actividad3/Ejemplo_Limpieza.ipynb Celda 30 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/elicobos/Desktop/Plataformas/Actividad3/Ejemplo_Limpieza.ipynb#X41sZmlsZQ%3D%3D?line=1'>2</a> vertical_concat = pd.concat([data2, data], axis=0)
#       <a href='vscode-notebook-cell:/Users/elicobos/Desktop/Plataformas/Actividad3/Ejemplo_Limpieza.ipynb#X41sZmlsZQ%3D%3D?line=4'>5</a> # Coloque los __DataFrames__ de lado a lado
# ----> <a href='vscode-notebook-cell:/Users/elicobos/Desktop/Plataformas/Actividad3/Ejemplo_Limpieza.ipynb#X41sZmlsZQ%3D%3D?line=5'>6</a> horizontal_concat = pd.concat([data2, fecha], axis=1)
#
# NameError: name 'fecha' is not defined
